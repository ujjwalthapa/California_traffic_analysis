# %%
# %matplotlib inline

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# File to Load (Remember to change these)
ca_dmv_peak_hours = "2017_peak_hours_report_kdfactor.csv"

# %%
# Read the City and Ride Data
ca_dmv_peak_hours = pd.read_csv(ca_dmv_peak_hours)

# Display the data table for preview
ca_dmv_peak_hours.head()
# Out:
#    DI  RTE   CO  PRE      PM     CS LEG  YR AM_DIR  AM_WAY_PHV  ...  AM_DAY  \
# 0  12    1  ORA  NaN  22.500  623.0   O  17      S        2536  ...     WED
# 1  12    1  ORA  NaN  30.141  937.0   A  16      N       14488  ...     FRI
# 2   7    1   LA  NaN  18.090    7.0   A  15      N        1143  ...     THU
# 3   7    1   LA  NaN  27.100  425.0   O  17      N        4363  ...     TUE
# 4   7    1   LA  NaN  40.769  720.0   A  16      N        2106  ...     MON
#
#    AM_MONTH  PM_DIR  PM_WAY_PHV PM_K_FACTOR_AMT PM_D_FACTOR_AMT PM_KD_FACTOR  \
# 0       NOV       N       2,596            8.92           78.86         7.03
# 1       JUN       S       3,012            7.82           75.49         5.90
# 2       OCT       S       1,321            8.02           56.31         4.52
# 3       OCT       N       3,980            7.66           62.80         4.81
# 4       FEB       N       2,742            9.64           58.20         5.61
#
#   PM_HOUR  PM_DAY  PM_MONTH
# ...

# %%
ca_dmv_peak_hours
# Out:
#       DI  RTE   CO  PRE      PM     CS LEG  YR AM_DIR  AM_WAY_PHV  ...  \
# 0     12    1  ORA  NaN  22.500  623.0   O  17      S        2536  ...
# 1     12    1  ORA  NaN  30.141  937.0   A  16      N       14488  ...
# 2      7    1   LA  NaN  18.090    7.0   A  15      N        1143  ...
# 3      7    1   LA  NaN  27.100  425.0   O  17      N        4363  ...
# 4      7    1   LA  NaN  40.769  720.0   A  16      N        2106  ...
# 5      7    1   LA  NaN  48.171   45.0   A  16      N        1440  ...
# 6      5    1   SB    R   0.000  517.0   A  17      S         752  ...
# 7      5    1   SB  NaN  19.251  296.0   B  16      S         886  ...
# 8      5    1   SB  NaN  20.565  518.0   A  17      S         528  ...
# 9      5    1   SB  NaN  22.519  294.0   O  17      N        1332  ...
# 10     5    1   SB    R  23.296  286.0   A  17      N        1117  ...
# 11     5    1   SB    R  26.690  288.0   A  17      N        1112  ...
# ...

# %%
ca_dmv_peak_hours.shape
# Out:
# (1412, 24)

# %%
ca_dmv_peak_hours.describe
# Out:
# <bound method NDFrame.describe of       DI  RTE   CO  PRE      PM     CS LEG  YR AM_DIR  AM_WAY_PHV  ...  \
# 0     12    1  ORA  NaN  22.500  623.0   O  17      S        2536  ...
# 1     12    1  ORA  NaN  30.141  937.0   A  16      N       14488  ...
# 2      7    1   LA  NaN  18.090    7.0   A  15      N        1143  ...
# 3      7    1   LA  NaN  27.100  425.0   O  17      N        4363  ...
# 4      7    1   LA  NaN  40.769  720.0   A  16      N        2106  ...
# 5      7    1   LA  NaN  48.171   45.0   A  16      N        1440  ...
# 6      5    1   SB    R   0.000  517.0   A  17      S         752  ...
# 7      5    1   SB  NaN  19.251  296.0   B  16      S         886  ...
# 8      5    1   SB  NaN  20.565  518.0   A  17      S         528  ...
# 9      5    1   SB  NaN  22.519  294.0   O  17      N        1332  ...
# 10     5    1   SB    R  23.296  286.0   A  17      N        1117  ...
# 11     5    1   SB    R  26.690  288.0   A  17      N        1112  ...
# ...

# %%
ca_dmv_peak_hours.columns
# Out:
# Index(['DI', 'RTE', 'CO', 'PRE', 'PM', 'CS', 'LEG', 'YR', 'AM_DIR',
#        'AM_WAY_PHV', 'AM_K_FACTOR_AMT', 'AM_D_FACTOR_AMT', 'AM_KD_FACTOR',
#        'AM_HOUR', 'AM_DAY', 'AM_MONTH', 'PM_DIR', 'PM_WAY_PHV',
#        'PM_K_FACTOR_AMT', 'PM_D_FACTOR_AMT', 'PM_KD_FACTOR', 'PM_HOUR',
#        'PM_DAY', 'PM_MONTH'],
#       dtype='object')

# %%
# Reference multiple columns within a DataFrame
ca_dmv_peak_hours[["CO", "AM_KD_FACTOR", "PM_KD_FACTOR", "AM_HOUR","PM_HOUR"]].head()
# Out:
#     CO  AM_KD_FACTOR  PM_KD_FACTOR  AM_HOUR  PM_HOUR
# 0  ORA          6.87          7.03        8       18
# 1  ORA         28.39          5.90        9       19
# 2   LA          3.91          4.52        8       17
# 3   LA          5.27          4.81        7       17
# 4   LA          4.31          5.61       12       17

# %%
# Identify incomplete rows
ca_dmv_peak_hours.count()
# Out:
# DI                 1412
# RTE                1412
# CO                 1412
# PRE                 449
# PM                 1412
# CS                 1411
# LEG                1412
# YR                 1412
# AM_DIR             1412
# AM_WAY_PHV         1412
# AM_K_FACTOR_AMT    1412
# AM_D_FACTOR_AMT    1412
# AM_KD_FACTOR       1412
# AM_HOUR            1412
# AM_DAY             1412
# AM_MONTH           1412
# PM_DIR             1412
# PM_WAY_PHV         1412
# PM_K_FACTOR_AMT    1412
# PM_D_FACTOR_AMT    1412
# PM_KD_FACTOR       1412
# PM_HOUR            1412
# PM_DAY             1412
# PM_MONTH           1412
# dtype: int64

# %%
# Drop all rows with missing information
df = ca_dmv_peak_hours.dropna(how='any')

# %%
df.count()
# Out:
# DI                 449
# RTE                449
# CO                 449
# PRE                449
# PM                 449
# CS                 449
# LEG                449
# YR                 449
# AM_DIR             449
# AM_WAY_PHV         449
# AM_K_FACTOR_AMT    449
# AM_D_FACTOR_AMT    449
# AM_KD_FACTOR       449
# AM_HOUR            449
# AM_DAY             449
# AM_MONTH           449
# PM_DIR             449
# PM_WAY_PHV         449
# PM_K_FACTOR_AMT    449
# PM_D_FACTOR_AMT    449
# PM_KD_FACTOR       449
# PM_HOUR            449
# PM_DAY             449
# PM_MONTH           449
# dtype: int64

# %%
# DAY (AM_SUMMARY)
#print AM_K_FACTOR_AMT
print(round(ca_dmv_peak_hours["AM_K_FACTOR_AMT"].sum()))


#print AM_D_FACTOR_AMT
print(round(ca_dmv_peak_hours["AM_D_FACTOR_AMT"].sum()))


#print AM_KD_FACTOR
print(round(ca_dmv_peak_hours["AM_KD_FACTOR"].sum()))
# Out:
# 14092.0
# 90285.0
# 9118.0

# %%
# NIGHT (PM_SUMMARY)
#print PM_K_FACTOR_AMT
print(round(ca_dmv_peak_hours["PM_K_FACTOR_AMT"].sum()))


#print PM_D_FACTOR_AMT
print(round(ca_dmv_peak_hours["PM_D_FACTOR_AMT"].sum()))


#print PM_KD_FACTOR
print(round(ca_dmv_peak_hours["PM_KD_FACTOR"].sum()))
# Out:
# 15193.0
# 87114.0
# 9541.0

# %%
# TESTING METHODS

# %%
R_type = ca_dmv_peak_hours.set_index('CO')['PM_HOUR']
R_type.value_counts()
# Out:
# 16    428
# 17    347
# 15    289
# 14    186
# 13    115
# 18     31
# 19      7
# 21      3
# 20      3
# 22      2
# 0       1
# Name: PM_HOUR, dtype: int64

# %%
print(ca_dmv_peak_hours["CO"].value_counts())
# Out:
# SD     138
# KER    113
# FRE     73
# LA      73
# TUL     66
# IMP     47
# SHA     46
# SAC     42
# SB      42
# INY     41
# SBD     38
# ORA     38
# MNO     34
# PLA     30
# SIS     29
# MAD     28
# BUT     25
# RIV     25
# SLO     25
# MEN     24
# SM      23
# SUT     22
# HUM     22
# KIN     22
# TEH     20
# SJ      20
# YOL     19
# SCL     19
# MON     19
# PLU     18
# VEN     17
# LAS     17
# CC      16
# NEV     15
# SOL     13
# MER     12
# ED      12
# YUB     12
# LAK     11
# TRI     11
# GLE     10
# ALA     10
# MOD      9
# STA      8
# SON      7
# DN       6
# MPA      6
# TUO      5
# SIE      5
# COL      5
# SF       4
# SBT      4
# AMA      4
# NAP      4
# MRN      3
# CAL      3
# ALP      1
# SCR      1
# Name: CO, dtype: int64

# %%
# Testing methods
Rc_Pc = len(ca_dmv_peak_hours["CO"].value_counts())
print(Rc_Pc)
# Out:
# 58

# %%
# Create a new DataFrame that looks into SF county
Sf_df = ca_dmv_peak_hours.loc[ca_dmv_peak_hours["CO"] == "SF"]
Sf_df
# Out:
#       DI  RTE  CO  PRE     PM     CS LEG  YR AM_DIR  AM_WAY_PHV  ...  AM_DAY  \
# 32     4    1  SF  NaN  4.050  103.0   B  16      N        2535  ...     SAT
# 868    4  101  SF  NaN  5.322  110.0   B  16      S        1725  ...     THU
# 869    4  101  SF  NaN  5.940  111.0   A  16      N        1484  ...     FRI
# 1301   4  280  SF    R  0.000  112.0   A  17      N        6420  ...     THU
#
#       AM_MONTH  PM_DIR  PM_WAY_PHV PM_K_FACTOR_AMT PM_D_FACTOR_AMT  \
# 32         OCT       S       2,505            6.70           52.55
# 868        NOV       N       1,691            6.21           59.40
# 869        MAY       N       1,963            6.68           68.07
# 1301       OCT       S       6,544            8.68           53.51
#
#      PM_KD_FACTOR PM_HOUR  PM_DAY  PM_MONTH
# 32           3.52      16     TUE       JAN
# 868          3.69      17     THU       AUG
# 869          4.55      17     FRI       MAY
# 1301         4.64      15     FRI       OCT
#
# ...

# %%
Sf_df.plot(kind="bar", figsize=(15,3))

# Set a title for the chart
plt.title("Average Cars in SF County")

#Add the legend.
legend = plt.legend(loc = "right")

legend.legendHandles[0]._sizes = [30]
legend.legendHandles[1]._sizes = [30]
legend.legendHandles[2]._sizes = [30]


plt.show()
plt.tight_layout()
